# %%
import os
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score, confusion_matrix, ConfusionMatrixDisplay, classification_report
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import to_categorical, img_to_array, load_img
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping

# %%
IMG_SIZE = (128, 128)
DATA_DIR = "Dataset/preprocessed_images"
META_CSV = "Dataset/meta_train.csv"
SEED = 42
EPOCHS = 15
BATCH_SIZE = 32

import random
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)

meta_df = pd.read_csv(META_CSV)
le = LabelEncoder()
meta_df["variety_encoded"] = le.fit_transform(meta_df["variety"])
num_classes = len(le.classes_)

# %%
X, y = [], []
for _, row in meta_df.iterrows():
    try:
        img_id = row["image_id"].replace(".jpg", "")
        label = row["label"]
        img_path = os.path.join(DATA_DIR, label, img_id + "_red.jpg")
        img = load_img(img_path, target_size=IMG_SIZE)
        img = img_to_array(img) / 255.0
        X.append(img)
        y.append(row["variety_encoded"])
    except FileNotFoundError:
        continue

X = np.array(X)
y = to_categorical(y, num_classes=num_classes)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=SEED)

# %%
model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(128, 128, 3)),
    MaxPooling2D((2, 2)),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Flatten(),
    Dense(128, activation='relu'),
    Dropout(0.5),
    Dense(num_classes, activation='softmax')
])

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
early_stop = EarlyStopping(patience=3, restore_best_weights=True)

datagen = ImageDataGenerator(
    rotation_range=5,
    width_shift_range=0.05,
    height_shift_range=0.05,
    zoom_range=0.05,
    horizontal_flip=True
)

history = model.fit(
    datagen.flow(X_train, y_train, batch_size=BATCH_SIZE),
    validation_data=(X_test, y_test),
    epochs=EPOCHS,
    callbacks=[early_stop]
)
# Out:
# Epoch 1/15
# 261/261 [==============================] - 30s 99ms/step - loss: 1.1776 - accuracy: 0.6830 - val_loss: 1.0610 - val_accuracy: 0.6695
# Epoch 2/15
# 261/261 [==============================] - 25s 97ms/step - loss: 1.0038 - accuracy: 0.7034 - val_loss: 0.9086 - val_accuracy: 0.6907
# Epoch 3/15
# 261/261 [==============================] - 25s 96ms/step - loss: 0.8847 - accuracy: 0.7154 - val_loss: 0.8970 - val_accuracy: 0.7181
# Epoch 4/15
# 261/261 [==============================] - 25s 96ms/step - loss: 0.8138 - accuracy: 0.7265 - val_loss: 0.7298 - val_accuracy: 0.7387
# Epoch 5/15
# 261/261 [==============================] - 25s 96ms/step - loss: 0.7419 - accuracy: 0.7530 - val_loss: 0.7086 - val_accuracy: 0.7618
# Epoch 6/15
# 261/261 [==============================] - 25s 96ms/step - loss: 0.6862 - accuracy: 0.7590 - val_loss: 0.5585 - val_accuracy: 0.8031
# Epoch 7/15
# 261/261 [==============================] - 25s 96ms/step - loss: 0.6290 - accuracy: 0.7822 - val_loss: 0.6063 - val_accuracy: 0.7959
# Epoch 8/15
# 261/261 [==============================] - 25s 96ms/step - loss: 0.6186 - accuracy: 0.7935 - val_loss: 0.5974 - val_accuracy: 0.7959
# Epoch 9/15
# 261/261 [==============================] - 25s 96ms/step - loss: 0.5791 - accuracy: 0.8020 - val_loss: 0.5145 - val_accuracy: 0.8300
# Epoch 10/15
# 261/261 [==============================] - 25s 97ms/step - loss: 0.5536 - accuracy: 0.8055 - val_loss: 0.4760 - val_accuracy: 0.8314
# Epoch 11/15
# 261/261 [==============================] - 25s 96ms/step - loss: 0.5233 - accuracy: 0.8151 - val_loss: 0.3979 - val_accuracy: 0.8727
# Epoch 12/15
# 261/261 [==============================] - 25s 96ms/step - loss: 0.5038 - accuracy: 0.8257 - val_loss: 0.4190 - val_accuracy: 0.8679
# Epoch 13/15
# 261/261 [==============================] - 25s 97ms/step - loss: 0.4693 - accuracy: 0.8394 - val_loss: 0.3990 - val_accuracy: 0.8727
# Epoch 14/15
# 261/261 [==============================] - 25s 96ms/step - loss: 0.4437 - accuracy: 0.8484 - val_loss: 0.4055 - val_accuracy: 0.8684

# %%
plt.plot(history.history['accuracy'], label='Train')
plt.plot(history.history['val_accuracy'], label='Validation')
plt.title('Model Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)
plt.show()

# %%
model.save("red_only_model.keras")

# %%
TEST_DIR = "Dataset/preprocessed_test_images"
all_files = os.listdir(TEST_DIR)
image_ids = sorted(set(f.split("_")[0] for f in all_files if f.endswith("_red.jpg")))

results = []
for img_id in image_ids:
    try:
        path = os.path.join(TEST_DIR, img_id + "_red.jpg")
        img = load_img(path, target_size=IMG_SIZE)
        img = img_to_array(img) / 255.0
        img = np.expand_dims(img, axis=0)

        pred = model.predict(img, verbose=0)
        predicted_variety = le.classes_[np.argmax(pred)]
        results.append({"image_id": img_id + ".jpg", "variety": predicted_variety})
    except Exception as e:
        print(f"Skipping {img_id}: {e}")

# %%
y_pred = model.predict(X_test)
y_pred_labels = np.argmax(y_pred, axis=1)
y_true_labels = np.argmax(y_test, axis=1)

acc = accuracy_score(y_true_labels, y_pred_labels)
print("Accuracy on test set:", acc)
# Out:
# 66/66 [==============================] - 1s 10ms/step
# Accuracy on test set: 0.872718539865514

# %%
cm = confusion_matrix(y_true_labels, y_pred_labels)
ConfusionMatrixDisplay(cm).plot()
