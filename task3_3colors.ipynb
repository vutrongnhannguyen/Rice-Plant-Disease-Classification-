# %%
import os
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
import cv2

from sklearn.model_selection import train_test_split

from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras.utils import Sequence
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, GlobalAveragePooling2D, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.regularizers import l2

# %%
class AgeDataGenerator(Sequence):
    def __init__(self, image_info_list, batch_size=16, img_size=(128, 128), shuffle=True):
        self.image_info = image_info_list
        self.batch_size = batch_size
        self.img_size = img_size
        self.shuffle = shuffle
        self.on_epoch_end()

    def __len__(self):
        return int(np.ceil(len(self.image_info) / self.batch_size))

    def __getitem__(self, index):
        batch_info = self.image_info[index * self.batch_size : (index + 1) * self.batch_size]
        X, y = self.__data_generation(batch_info)
        return X, y

    def on_epoch_end(self):
        if self.shuffle:
            np.random.shuffle(self.image_info)

    def __data_generation(self, batch_info):
        X = []
        y = []
        for img_path, age in batch_info:
            try:
                img = cv2.imread(img_path)
                img = cv2.resize(img, self.img_size)
                img = img.astype(np.float32) / 255.0
                X.append(img)
                y.append(age)
            except:
                continue
        return np.array(X), np.array(y)

# %%
metadata_path = "Dataset/meta_train.csv"
metadata_df = pd.read_csv(metadata_path)
metadata_df.set_index('image_id', inplace=True)

image_info_list = []
base_path = "Dataset/preprocessed_images"
labels = os.listdir(base_path)

for label in labels:
    folder = os.path.join(base_path, label)
    image_files = os.listdir(folder)
    base_names = sorted(set(f.split('_')[0] for f in image_files))

    for base in base_names:
        red = os.path.join(folder, f"{base}_red.jpg")
        green = os.path.join(folder, f"{base}_green.jpg")
        blue = os.path.join(folder, f"{base}_blue.jpg")
        if not all(os.path.exists(p) for p in [red, green, blue]):
            continue

        stacked_path = os.path.join(folder, f"{base}_stacked.jpg")
        if not os.path.exists(stacked_path):
            r = cv2.imread(red, cv2.IMREAD_GRAYSCALE)
            g = cv2.imread(green, cv2.IMREAD_GRAYSCALE)
            b = cv2.imread(blue, cv2.IMREAD_GRAYSCALE)
            stacked = np.stack([r, g, b], axis=-1)
            cv2.imwrite(stacked_path, stacked)

        image_id = base + ".jpg"
        if image_id in metadata_df.index:
            age = float(metadata_df.loc[image_id, "age"])
            image_info_list.append((stacked_path, age))

# %%
train_list, val_list = train_test_split(image_info_list, test_size=0.2, random_state=42)
train_gen = AgeDataGenerator(train_list, batch_size=16, img_size=(128, 128))
val_gen = AgeDataGenerator(val_list, batch_size=16, img_size=(128, 128))

# %%
input_tensor = Input(shape=(128, 128, 3))
base_model = EfficientNetB0(include_top=False, weights=None, input_tensor=input_tensor)

x = GlobalAveragePooling2D()(base_model.output)
x = Dense(256, activation='relu', kernel_regularizer=l2(0.05))(x)
x = Dropout(0.7)(x)
x = BatchNormalization()(x)
x = Dense(128, activation='relu', kernel_regularizer=l2(0.01))(x)
output = Dense(1, activation='linear')(x)

model = Model(inputs=base_model.input, outputs=output)

lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate=0.001,
    decay_steps=1000,
    decay_rate=0.9
)
optimizer = Adam(learning_rate=lr_schedule)

model.compile(optimizer=optimizer, loss='mae', metrics=['mae'])

# %%
history = model.fit(
    train_gen,
    validation_data=val_gen,
    epochs=60,
)
# Out:
# Epoch 1/60
# 521/521 [==============================] - 110s 188ms/step - loss: 22.2677 - mae: 17.4696 - val_loss: 10.8127 - val_mae: 7.4645
# Epoch 2/60
# 521/521 [==============================] - 63s 121ms/step - loss: 12.9458 - mae: 9.6975 - val_loss: 11.0285 - val_mae: 7.9324
# Epoch 3/60
# 521/521 [==============================] - 64s 123ms/step - loss: 11.2363 - mae: 8.6628 - val_loss: 10.0663 - val_mae: 7.7462
# Epoch 4/60
# 521/521 [==============================] - 65s 125ms/step - loss: 10.8544 - mae: 8.4346 - val_loss: 9.6918 - val_mae: 7.4462
# Epoch 5/60
# 521/521 [==============================] - 62s 118ms/step - loss: 10.0590 - mae: 8.0856 - val_loss: 9.8742 - val_mae: 8.1897
# Epoch 6/60
# 521/521 [==============================] - 61s 117ms/step - loss: 9.7393 - mae: 8.0741 - val_loss: 9.3206 - val_mae: 7.5837
# Epoch 7/60
# 521/521 [==============================] - 55s 105ms/step - loss: 9.6953 - mae: 8.0735 - val_loss: 9.0382 - val_mae: 7.4924
# Epoch 8/60
# 521/521 [==============================] - 53s 102ms/step - loss: 9.0873 - mae: 7.7391 - val_loss: 8.6819 - val_mae: 7.3720
# Epoch 9/60
# 521/521 [==============================] - 53s 102ms/step - loss: 8.9154 - mae: 7.7184 - val_loss: 8.4575 - val_mae: 7.3735
# Epoch 10/60
# 521/521 [==============================] - 53s 103ms/step - loss: 8.9888 - mae: 7.7887 - val_loss: 8.3585 - val_mae: 7.3339
# Epoch 11/60
# 521/521 [==============================] - 53s 102ms/step - loss: 8.6179 - mae: 7.6845 - val_loss: 8.3683 - val_mae: 7.5368
# Epoch 12/60
# 521/521 [==============================] - 54s 103ms/step - loss: 8.4736 - mae: 7.6610 - val_loss: 8.5327 - val_mae: 7.7127
# Epoch 13/60
# 521/521 [==============================] - 53s 102ms/step - loss: 8.3915 - mae: 7.6231 - val_loss: 9.2896 - val_mae: 8.4936
# Epoch 14/60
# 521/521 [==============================] - 54s 103ms/step - loss: 8.4543 - mae: 7.7146 - val_loss: 8.2072 - val_mae: 7.5493
# Epoch 15/60
# 521/521 [==============================] - 53s 102ms/step - loss: 8.1179 - mae: 7.4978 - val_loss: 8.3921 - val_mae: 7.7615
# Epoch 16/60
# 521/521 [==============================] - 54s 103ms/step - loss: 7.9914 - mae: 7.3254 - val_loss: 7.8025 - val_mae: 7.1265
# Epoch 17/60
# 521/521 [==============================] - 54s 103ms/step - loss: 7.9056 - mae: 7.2284 - val_loss: 7.8370 - val_mae: 7.1840
# Epoch 18/60
# 521/521 [==============================] - 53s 102ms/step - loss: 7.8511 - mae: 7.2291 - val_loss: 7.7021 - val_mae: 7.1377
# Epoch 19/60
# 521/521 [==============================] - 53s 102ms/step - loss: 7.8142 - mae: 7.2445 - val_loss: 7.9047 - val_mae: 7.3556
# Epoch 20/60
# 521/521 [==============================] - 54s 103ms/step - loss: 7.4907 - mae: 7.0019 - val_loss: 8.1318 - val_mae: 7.6523
# Epoch 21/60
# 521/521 [==============================] - 53s 102ms/step - loss: 7.4153 - mae: 6.9507 - val_loss: 9.0418 - val_mae: 8.6042
# Epoch 22/60
# 521/521 [==============================] - 53s 102ms/step - loss: 7.1436 - mae: 6.7216 - val_loss: 6.8979 - val_mae: 6.4813
# Epoch 23/60
# 521/521 [==============================] - 53s 102ms/step - loss: 7.0155 - mae: 6.5984 - val_loss: 6.7607 - val_mae: 6.3533
# Epoch 24/60
# 521/521 [==============================] - 53s 102ms/step - loss: 6.8880 - mae: 6.4719 - val_loss: 7.4565 - val_mae: 7.0687
# Epoch 25/60
# 521/521 [==============================] - 53s 102ms/step - loss: 6.7352 - mae: 6.3561 - val_loss: 12.7763 - val_mae: 12.4225
# Epoch 26/60
# 521/521 [==============================] - 53s 102ms/step - loss: 6.6205 - mae: 6.2671 - val_loss: 7.2762 - val_mae: 6.9367
# Epoch 27/60
# 521/521 [==============================] - 53s 102ms/step - loss: 6.3439 - mae: 6.0148 - val_loss: 6.6092 - val_mae: 6.2701
# Epoch 28/60
# 521/521 [==============================] - 53s 102ms/step - loss: 6.3221 - mae: 5.9931 - val_loss: 8.5502 - val_mae: 8.2282
# Epoch 29/60
# 521/521 [==============================] - 53s 102ms/step - loss: 6.1087 - mae: 5.7961 - val_loss: 10.1389 - val_mae: 9.8332
# Epoch 30/60
# 521/521 [==============================] - 53s 102ms/step - loss: 5.8055 - mae: 5.4991 - val_loss: 13.1514 - val_mae: 12.8373
# Epoch 31/60
# 521/521 [==============================] - 53s 102ms/step - loss: 5.7572 - mae: 5.4544 - val_loss: 12.4936 - val_mae: 12.1889
# Epoch 32/60
# 521/521 [==============================] - 53s 102ms/step - loss: 5.5769 - mae: 5.2787 - val_loss: 7.0828 - val_mae: 6.7928
# Epoch 33/60
# 521/521 [==============================] - 53s 102ms/step - loss: 5.3436 - mae: 5.0538 - val_loss: 7.5128 - val_mae: 7.2306
# Epoch 34/60
# 521/521 [==============================] - 53s 102ms/step - loss: 5.0802 - mae: 4.8053 - val_loss: 6.3342 - val_mae: 6.0588
# Epoch 35/60
# 521/521 [==============================] - 53s 102ms/step - loss: 4.8960 - mae: 4.6296 - val_loss: 6.1316 - val_mae: 5.8760
# Epoch 36/60
# 521/521 [==============================] - 53s 102ms/step - loss: 4.7760 - mae: 4.5213 - val_loss: 6.2758 - val_mae: 6.0264
# Epoch 37/60
# 521/521 [==============================] - 53s 102ms/step - loss: 4.5323 - mae: 4.2850 - val_loss: 5.6659 - val_mae: 5.4256
# Epoch 38/60
# 521/521 [==============================] - 53s 102ms/step - loss: 4.4631 - mae: 4.2293 - val_loss: 5.3978 - val_mae: 5.1691
# Epoch 39/60
# 521/521 [==============================] - 53s 102ms/step - loss: 4.3973 - mae: 4.1698 - val_loss: 6.1756 - val_mae: 5.9523
# Epoch 40/60
# 521/521 [==============================] - 53s 101ms/step - loss: 4.3261 - mae: 4.1068 - val_loss: 5.8580 - val_mae: 5.6411
# Epoch 41/60
# 521/521 [==============================] - 53s 102ms/step - loss: 4.2776 - mae: 4.0655 - val_loss: 6.0070 - val_mae: 5.7951
# Epoch 42/60
# 521/521 [==============================] - 53s 102ms/step - loss: 4.2681 - mae: 4.0603 - val_loss: 5.5789 - val_mae: 5.3751
# Epoch 43/60
# 521/521 [==============================] - 53s 102ms/step - loss: 4.0953 - mae: 3.8930 - val_loss: 5.5932 - val_mae: 5.3929
# Epoch 44/60
# 521/521 [==============================] - 53s 102ms/step - loss: 3.9868 - mae: 3.7887 - val_loss: 5.5696 - val_mae: 5.3722
# Epoch 45/60
# 521/521 [==============================] - 53s 102ms/step - loss: 4.0489 - mae: 3.8551 - val_loss: 5.3164 - val_mae: 5.1248
# Epoch 46/60
# 521/521 [==============================] - 56s 107ms/step - loss: 3.9664 - mae: 3.7766 - val_loss: 5.2677 - val_mae: 5.0808
# Epoch 47/60
# 521/521 [==============================] - 53s 103ms/step - loss: 3.8605 - mae: 3.6765 - val_loss: 5.7799 - val_mae: 5.5976
# Epoch 48/60
# 521/521 [==============================] - 53s 102ms/step - loss: 3.7714 - mae: 3.5903 - val_loss: 5.2685 - val_mae: 5.0887
# Epoch 49/60
# 521/521 [==============================] - 53s 101ms/step - loss: 3.6807 - mae: 3.5025 - val_loss: 5.2521 - val_mae: 5.0756
# Epoch 50/60
# 521/521 [==============================] - 53s 102ms/step - loss: 3.6689 - mae: 3.4927 - val_loss: 5.4484 - val_mae: 5.2749
# Epoch 51/60
# 521/521 [==============================] - 53s 101ms/step - loss: 3.7505 - mae: 3.5774 - val_loss: 5.5020 - val_mae: 5.3298
# Epoch 52/60
# 521/521 [==============================] - 53s 102ms/step - loss: 3.6308 - mae: 3.4602 - val_loss: 5.2259 - val_mae: 5.0563
# Epoch 53/60
# 521/521 [==============================] - 53s 101ms/step - loss: 3.6123 - mae: 3.4439 - val_loss: 5.2210 - val_mae: 5.0530
# Epoch 54/60
# 521/521 [==============================] - 53s 102ms/step - loss: 3.5744 - mae: 3.4086 - val_loss: 5.2534 - val_mae: 5.0909
# Epoch 55/60
# 521/521 [==============================] - 53s 101ms/step - loss: 3.6077 - mae: 3.4459 - val_loss: 5.2099 - val_mae: 5.0510
# Epoch 56/60
# 521/521 [==============================] - 55s 105ms/step - loss: 3.5824 - mae: 3.4253 - val_loss: 5.1102 - val_mae: 4.9554
# Epoch 57/60
# 521/521 [==============================] - 56s 108ms/step - loss: 3.4782 - mae: 3.3234 - val_loss: 5.1997 - val_mae: 5.0456
# Epoch 58/60
# 521/521 [==============================] - 57s 109ms/step - loss: 3.4877 - mae: 3.3347 - val_loss: 5.1735 - val_mae: 5.0214
# Epoch 59/60
# 521/521 [==============================] - 55s 105ms/step - loss: 3.4789 - mae: 3.3273 - val_loss: 5.2138 - val_mae: 5.0628
# Epoch 60/60
# 521/521 [==============================] - 53s 102ms/step - loss: 3.4040 - mae: 3.2540 - val_loss: 5.0690 - val_mae: 4.9199

# %%
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Train Loss (MSE)')
plt.plot(history.history['val_loss'], label='Val Loss (MSE)')
plt.title('Training vs Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('MSE')
plt.legend()
plt.grid(True)


plt.subplot(1, 2, 2)
plt.plot(history.history['mae'], label='Train MAE')
plt.plot(history.history['val_mae'], label='Val MAE')
plt.title('Training vs Validation MAE')
plt.xlabel('Epochs')
plt.ylabel('MAE')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.savefig("epoch-accuracy-task3.svg", bbox_inches="tight")
plt.show()

# %%
TEST_DIR = "Dataset/preprocessed_test_images"
OUTPUT_CSV = "task3_rgb_predictions.csv"
MODEL_INPUT_SIZE = (128, 128)

all_files = os.listdir(TEST_DIR)
image_ids = sorted(set(f.split("_")[0] for f in all_files if f.endswith("_red.jpg")))

results = []

for img_id in image_ids:
    try:
        red_path = os.path.join(TEST_DIR, f"{img_id}_red.jpg")
        green_path = os.path.join(TEST_DIR, f"{img_id}_green.jpg")
        blue_path = os.path.join(TEST_DIR, f"{img_id}_blue.jpg")

        if not all(os.path.exists(p) for p in [red_path, green_path, blue_path]):
            print(f"Missing channel for {img_id}, skipping...")
            continue

        r = cv2.imread(red_path, cv2.IMREAD_GRAYSCALE)
        g = cv2.imread(green_path, cv2.IMREAD_GRAYSCALE)
        b = cv2.imread(blue_path, cv2.IMREAD_GRAYSCALE)

        r = cv2.resize(r, MODEL_INPUT_SIZE)
        g = cv2.resize(g, MODEL_INPUT_SIZE)
        b = cv2.resize(b, MODEL_INPUT_SIZE)

        stacked = np.stack([r, g, b], axis=-1).astype(np.float32) / 255.0

        img_input = np.expand_dims(stacked, axis=0)

        pred = model.predict(img_input, verbose=0)[0][0]

        results.append({
            "image_id": img_id + ".jpg",
            "age": round(pred, 2)
        })

    except Exception as e:
        print(f"Error processing {img_id}: {e}")

df = pd.DataFrame(results)
df.to_csv(OUTPUT_CSV, index=False)
print(f"Saved predictions to {OUTPUT_CSV}")
# Out:
# Saved predictions to task3_rgb_predictions.csv

# %%
model.save("task3_3colors.keras")
